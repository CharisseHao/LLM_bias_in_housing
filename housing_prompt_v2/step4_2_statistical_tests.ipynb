# %% [markdown]
# ## Step 4.2: Statistical Tests (Kruskal-Wallis and Dunn's Tests)
#
# Depends on:
# - csv.zip file generated in step 3 containing all results and metadata: `processed_data/housing_prompt_v2_allmodels.csv.zip`
#
# Outputs: no files, only results in notebook

# %%
import sys
sys.path.append('../src/')
from stat_tests import assumptions_and_tests, detailed_dunns_test_bivariate, detailed_dunns_test

import pandas as pd
import seaborn as sns
import datetime


import warnings
warnings.filterwarnings("ignore")

sns.set_theme(context='notebook', style='whitegrid')
pd.set_option("display.max_rows", 100)

# %%
start_run = datetime.datetime.now()

# %%
df = pd.read_csv("processed_data/housing_prompt_v2_allmodels.csv.zip", compression='zip')
df_valid = df[df['query_response'].notna()]
df_valid.head()
# Out:
#   custom_id                 model              name gender   race  \
# 0    task-0  google/gemma-2-2b-it  Charlie Andersen    Man  Anglo
# 1    task-1  google/gemma-2-2b-it  Charlie Andersen    Man  Anglo
# 2    task-2  google/gemma-2-2b-it  Charlie Andersen    Man  Anglo
# 3    task-3  google/gemma-2-2b-it  Charlie Andersen    Man  Anglo
# 4    task-4  google/gemma-2-2b-it  Charlie Andersen    Man  Anglo
#
#   credit_scores               eviction query_response_raw  query_response  \
# 0           500  no record of eviction   Score: 20/100 \n            20.0
# 1           500  no record of eviction   Score: 25/100 \n            25.0
# 2           500  no record of eviction   Score: 25/100 \n            25.0
# 3           600  no record of eviction   Score: 55/100 \n            55.0
# 4           600  no record of eviction   Score: 65/100 \n            65.0
#
#    query_response_raw_len  refused
# 0                      15        0
# 1                      15        0
# ...

# %% [markdown]
# ## Single Variable

# %%
variables = ['gender', 'race', 'eviction', 'credit_scores']
models = df_valid['model'].unique()
assumptions_and_tests(df_valid, 'query_response', models, variables)
# Out:
# variable: gender
# model: google/gemma-2-2b-it
# Checking Normality (Shapiro-Wilk Test) for each age group:
#   Normality check failed: 3 out of 3 groups failed
# Checking Homogeneity of Variance (Levene's Test) for age groups:
#   Levene's test p-value = 0.4353333677359268
#   Homogeneity of variances check passed! Variances are equal across groups (p > 0.05)
# Kruskal-Wallis Test:
#   test statistic: 7.047473633493603; p-value: 0.02948903390597137
#   Significant difference between groups
# <style type="text/css">
# #T_78e51_row0_col7, #T_78e51_row0_col8, #T_78e51_row1_col8, #T_78e51_row2_col8 {
#   background-color: lightcoral;
# }
# #T_78e51_row1_col7, #T_78e51_row2_col7 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_78e51">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78e51_level0_col0" class="col_heading level0 col0" >gender1</th>
#       <th id="T_78e51_level0_col1" class="col_heading level0 col1" >gender2</th>
# ...

# %% [markdown]
# ## Multiple Variables

# %%
# credit_scores x gender
var1 = 'credit_scores'
var2 = 'gender'

for m in models:
    print(f"\033[1mmodel: {m}\033[0m")
    model_df = df_valid[df_valid['model'].str.contains(m)]
    display(detailed_dunns_test_bivariate(model_df, 'query_response', var1, var2, total_comparisons=10000))
# Out:
# model: google/gemma-2-2b-it
# <style type="text/css">
# #T_26037_row0_col5, #T_26037_row0_col6, #T_26037_row1_col5, #T_26037_row1_col6, #T_26037_row2_col5, #T_26037_row2_col6, #T_26037_row3_col5, #T_26037_row3_col6, #T_26037_row4_col5, #T_26037_row4_col6, #T_26037_row5_col5, #T_26037_row5_col6, #T_26037_row6_col5, #T_26037_row6_col6, #T_26037_row7_col5, #T_26037_row7_col6, #T_26037_row8_col5, #T_26037_row8_col6, #T_26037_row9_col5, #T_26037_row9_col6, #T_26037_row10_col5, #T_26037_row10_col6, #T_26037_row11_col5, #T_26037_row11_col6, #T_26037_row12_col5, #T_26037_row12_col6, #T_26037_row13_col5, #T_26037_row13_col6, #T_26037_row14_col5, #T_26037_row14_col6, #T_26037_row15_col5, #T_26037_row15_col6, #T_26037_row16_col5, #T_26037_row16_col6, #T_26037_row17_col5, #T_26037_row17_col6 {
#   background-color: lightcoral;
# }
# </style>
# <table id="T_26037">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
# ...

# %%
# credit_scores x race
var1 = 'credit_scores'
var2 = 'race'

for m in models:
    print(f"\033[1mmodel: {m}\033[0m")
    model_df = df_valid[df_valid['model'].str.contains(m)]
    display(detailed_dunns_test_bivariate(model_df, 'query_response', var1, var2, total_comparisons=10000))
# Out:
# model: google/gemma-2-2b-it
# <style type="text/css">
# ...

# %%
# credit_scores x eviction
var1 = 'credit_scores'
var2 = 'eviction'

for m in models:
    print(f"\033[1mmodel: {m}\033[0m")
    model_df = df_valid[df_valid['model'].str.contains(m)]
    display(detailed_dunns_test_bivariate(model_df, 'query_response', var1, var2, total_comparisons=10000))
# Out:
# model: google/gemma-2-2b-it
# <style type="text/css">
# ...

# %%
# eviction x gender
var1 = 'eviction'
var2 = 'gender'

for m in models:
    print(f"\033[1mmodel: {m}\033[0m")
    model_df = df_valid[df_valid['model'].str.contains(m)]
    display(detailed_dunns_test_bivariate(model_df, 'query_response', var1, var2, total_comparisons=10000))
# Out:
# model: google/gemma-2-2b-it
# <style type="text/css">
# #T_ddfab_row0_col5, #T_ddfab_row0_col6, #T_ddfab_row1_col5, #T_ddfab_row1_col6, #T_ddfab_row2_col5, #T_ddfab_row2_col6, #T_ddfab_row3_col5, #T_ddfab_row3_col6, #T_ddfab_row4_col5, #T_ddfab_row4_col6, #T_ddfab_row5_col5, #T_ddfab_row5_col6, #T_ddfab_row6_col5, #T_ddfab_row6_col6, #T_ddfab_row7_col5, #T_ddfab_row7_col6, #T_ddfab_row8_col5, #T_ddfab_row8_col6, #T_ddfab_row9_col5, #T_ddfab_row9_col6, #T_ddfab_row10_col5, #T_ddfab_row10_col6, #T_ddfab_row11_col5, #T_ddfab_row11_col6, #T_ddfab_row12_col5, #T_ddfab_row12_col6, #T_ddfab_row13_col5, #T_ddfab_row13_col6, #T_ddfab_row14_col5, #T_ddfab_row14_col6 {
#   background-color: lightcoral;
# }
# </style>
# <table id="T_ddfab">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ddfab_level0_col0" class="col_heading level0 col0" >median_diff</th>
# ...

# %%
# eviction x race
var1 = 'eviction'
var2 = 'race'

for m in models:
    print(f"\033[1mmodel: {m}\033[0m")
    model_df = df_valid[df_valid['model'].str.contains(m)]
    display(detailed_dunns_test_bivariate(model_df, 'query_response', var1, var2, total_comparisons=10000))
# Out:
# model: google/gemma-2-2b-it
# <style type="text/css">
# ...

# %%
# race x gender
var1 = 'race'
var2 = 'gender'

for m in models:
    print(f"\033[1mmodel: {m}\033[0m")
    model_df = df_valid[df_valid['model'].str.contains(m)]
    display(detailed_dunns_test_bivariate(model_df, 'query_response', var1, var2, total_comparisons=10000))
# Out:
# model: google/gemma-2-2b-it
# <style type="text/css">
# ...

# %%
print("Elapsed time:", datetime.datetime.now() - start_run)
# Out:
# Elapsed time: 0:00:15.286736
